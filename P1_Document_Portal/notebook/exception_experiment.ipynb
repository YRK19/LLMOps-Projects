# %%
import sys
import traceback

# %%
from logger.custom_logger import CustomLogger
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from logger.custom_logger import CustomLogger
#
# ModuleNotFoundError: No module named 'logger'

# %%
class DocumentPortalException(Exception):
    """Custom exception for Document Portal errors."""
    def __init__(self,error_message,error_details:sys):
        _,_,exc_tb=error_details.exc_info()
        self.file_name = exc_tb.tb_frame.f_code.co_filename
        self.line_number = exc_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))

    def __str__(self):
        return f"""
            Error in [{self.file_name}] at line [{self.line_number}]
            message: {self.error_message}
            Traceback: {self.traceback_str}
            """


if __name__ == "__main__":
    try:
        a = 1 / 0  # This will raise a ZeroDivisionError
        print(a)
    except Exception as e:
        app_exc = DocumentPortalException(e,sys)
        raise app_exc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 20
#      19 try:
# ---> 20     a = 1 / 0  # This will raise a ZeroDivisionError
#      21     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[2], line 24
#      22 except Exception as e:
#      23     app_exc = DocumentPortalException(e,sys)
# ---> 24     raise app_exc
#
# DocumentPortalException:
#             Error in [/var/folders/k5/6cjr_b0s7fv23nv__f1hnnrm0000gn/T/ipykernel_27942/34228288.py] at line [20]
#             message: division by zero
#             Traceback: Traceback (most recent call last):
#   File "/var/folders/k5/6cjr_b0s7fv23nv__f1hnnrm0000gn/T/ipykernel_27942/34228288.py", line 20, in <module>
#     a = 1 / 0  # This will raise a ZeroDivisionError
#         ~~^~~
# ZeroDivisionError: division by zero
# ERROR! Session/line number was not unique in database. History logging moved to new session 27
